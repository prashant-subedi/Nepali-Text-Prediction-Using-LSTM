# %%
from nltk.corpus import PlaintextCorpusReader
import sys
wordlists = PlaintextCorpusReader("Nepali_Corpus", '.*txt')

# %%
texts,invalid = [],0
for i in wordlists.fileids():
    try:
        texts.append(wordlists.raw(i).replace("\ufeff",""))
    except UnicodeDecodeError:
        invalid+=1

# %%
len(wordlists.fileids())
# Out:
# 20954

# %%
print(len(texts),invalid)
# Out:
# 20727 227

# %%
import re
##Split in text
paragraph = list()
for text in texts:
    raw = re.split(r"\n|\r",text.strip())
    if len(text) > 0 or not re.match('(\s)+',text): 
        paragraph.extend(raw)
print(len(paragraph))
# Out:
# 244816

# %%
#paragraph

# %%
#Split Into Sentences
pura_sents = []
for i in paragraph:
    pura_sents.extend(re.split(r'(?<=।)\s',i))
print(len(pura_sents))
# Out:
# 543907

# %%
sents = []
for i in pura_sents:
    sents.extend(re.split(r'(?<=\?)\s',i))
#sents
print(len(sents))
# Out:
# 553131

# %%
#Split Into Words
tokenized_sents = []
for i in sents:
    tok_sent = [j for j in  re.split(r"\s+|\t+|[-(),।/'–’“‘]|\"‘|\.+|[०१२३४५६७८९]+",i) if len(j)>0]
    tokenized_sents.append(tok_sent)

# %%
#tokenized_sents

# %%
vocab = set()
total = []
for i in tokenized_sents:
    vocab.update(i)
    total.extend(i)

print("Total Sentences =",len(tokenized_sents))
print("Vocab Size=", len(vocab))
print(""len(total))
# Out:
# 553131
# 343699
# 6777814

# %%
from nltk import FreqDist
a = FreqDist(total)
a.plot(200)

# %%
with open("text_dump","w") as text_dump:
    for i in a.most_common():
        text_dump.write(i[0]+"-------"+ str(i[1]))
        text_dump.write("\n")
text_dump.close()
print("Dump Completed")
# Out:
# Dump Completed

# %%
frequency_analysis = [i[1] for i in a.most_common()]
frequency = FreqDist(frequency_analysis)
frequency.most_common()

with open("frequency_dump","w") as text_dump:
    for i in a.most_common():
        text_dump.write(i[0]+"-------"+ str(i[1]))
        text_dump.write("\n")
text_dump.close()
print("Dump Completed")
frequency.plot(100)
#The plot shows a asymptotical decrease in frequency of words.
#There are a large number of words whose frequeny is just 1 in a huge vocab
# Out:
# Dump Completed

# %%
print(sys.getsizeof(tokenized_sents))
#This can't be right !!
# Out:
# 4826312

# %%
train = tokenized_sents[0:200]

# %%
print(train)
# Out:
# [['मकवानपुर', 'फिल्म', 'हुर्रे', 'ले', 'रिलिज', 'मिति', 'नजिकिएसँगै', 'प्रचारप्रसारमा', 'तीव्रता', 'दिएको', 'छ'], ['शनिबार', 'हेटौंडा', 'आइपुगेको', 'फिल्मको', 'निर्माता', 'तथा', 'कलाकारको', 'टोलीले', 'फिल्म', 'हास्यप्रधान', 'रहे', 'पनि', 'पृथक', 'कथाबस्तुमा', 'निर्माण', 'रहेको', 'बताए'], ['फिल्मको', 'प्रचारका', 'लागि', 'देश', 'दौडाहामा', 'रहेको', 'फिल्मको', 'टोली', 'पोखरा', 'बुटवल', 'चितवनपछि', 'हेटौंडा', 'आइपुगेको', 'थियो'], ['हेटौंडामा', 'आयोजित', 'अन्तरक्रियामा', 'अभिनेता', 'अनुपविक्रम', 'शाहीले', 'फिल्म', 'मनोरञ्जक', 'रहेको', 'बताए', 'भने', 'अभिनेत्री', 'केकी', 'अधिकारीले', 'फिल्मभित्र', 'आफू', 'सबैलाई', 'मोहमा', 'फसाएर', 'राख्ने', 'स्वर्गकी', 'अप्सरा', 'मेनका', 'को', 'जस्तै', 'भूमिकामा', 'रहेको', 'बताइन्'], ['हास्य', 'कलाकार', 'राजाराम', 'पौडेलले', 'एक', 'महिना', 'सुटिङ', 'गर्दा', 'आर्यघाटको', 'धुँवाले', 'कलाकारहरू', 'बिरामी', 'परेको', 'बताए'], ['फिल्म', 'हेरेपछि', 'हाँस्दा', 'हाँस्दा', 'भोक', 'लाग्छ', 'उनले', 'रमाइलो', 'गर्दै', 'भने', 'सबै', 'फिल्ममा', 'सन्देश', 'राख्दा', 'मजा', 'हुँदैन', 'सन्देश', 'मात्र', 'खोज्ने', 'भए', 'पुराण', 'सुने', 'भैगो', 'नि'], ['यम', 'थापाको', 'लेखन', 'तथा', 'निर्देशन', 'रहेको', 'फिल्ममा', 'अनुपविक्रम', 'शाही', 'केकी', 'अधिकारी', 'बिजय', 'बराल', 'अंकित', 'खड्का', 'संगीता', 'नापित', 'लगायतको', 'अभिनय', 'छ'], ['फागुनको', 'गतेबाट', 'प्रदर्शित', 'हुने', 'फिल्मलाई', 'याखा', 'इन्टरटेनमेन्टको', 'ब्यानरमा', 'दावा', 'शेर्पा', 'सोनम', 'लामा', 'भ्लोन', 'र', 'छिरिङ', 'दोर्जे', 'शेर्पाले', 'निर्माण', 'गरेका', 'हुन्'], ['काठमाडौं', 'मोक्षदा', 'स्कुलको', 'मञ्जरी', 'थिएटरमा', 'उड्की', 'मुड्की', 'नाटक', 'मञ्चन', 'सुरु', 'भएको', 'छ'], ['रंगकर्मी', 'सुरेश', 'चन्दद्वारा', 'निर्देशित', 'उड्की', 'मुड्कीमा', 'मोक्षदा', 'स्कुलमा', 'अध्ययनरत', 'कक्षा', 'देखि', 'सम्मका', 'छात्रछात्राको', 'अभिनय', 'रहेको', 'छ'], ['स्पेस', 'नाट्य', 'संस्था', 'र', 'मञ्जरी', 'थिएटरद्वारा', 'संयुक्त', 'रूपमा', 'शुक्रबार', 'मञ्चन', 'गरिएको', 'नाटकको', 'पहिलो', 'सोमा', 'काठमाडौं', 'क्षेत्र', 'नं', 'का', 'सांसद', 'गगन', 'थापा', 'विभिन्न', 'स्कुलका', 'प्रिन्सिपल', 'पत्रकार', 'शिक्षक', 'शिक्षिका', 'अभिभावक', 'तथा', 'विद्यार्थीको', 'उपस्थिति', 'थियो'], ['उड्की', 'मुड्कीले', 'एउटा', 'स्कुलको', 'कक्षाकोठाभित्रको', 'संसारलाई', 'रंगमञ्चमा', 'उतारेको', 'छ'], ['विद्यार्थीका', 'छुकछुके', 'बानी', 'झिनामसिना', 'झैझगडा', 'बालसुलभ', 'बद्मासीलाई', 'नाटकले', 'विषय', 'बनाएको', 'छ'], ['बालबालिकालाई', 'गाली', 'नगरी', 'नरिसाई', 'माया', 'गरेरै', 'पनि', 'सिकाउन', 'बुझाउन', 'र', 'अनुशासनमा', 'राख्न', 'सकिन्छ', 'भन्ने', 'पक्षलाई', 'नाटककी', 'शिक्षिकामार्फत', 'उजागर', 'गर्ने', 'कोसिस', 'गरिएको', 'छ'], ['नाटकमा', 'विद्यार्थीको', 'उटुंग्याहा', 'रमाइला', 'क्रियाकलाप', 'देख्दा', 'दर्शक', 'पेट', 'मिचीमिची', 'हाँस्छन्'], ['जब', 'नाटकमा', 'विद्यार्थीले', 'जुम्लाकी', 'एक', 'महिलाको', 'द्वन्द्वकालीन', 'व्यथा', 'सुनाउँछन्', 'त्यतिखेर', 'दर्शकहरू', 'विगतको', 'राजनीतिक', 'द्वन्द्वका', 'बाछिटाहरू', 'सम्झेर', 'भावुक', 'हुन्छन्'], ['शिक्षिकाको', 'भूमिकामा', 'अभिनय', 'गरिरहेकी', 'कक्षा', 'की', 'छात्रा', 'उपहार', 'लिम्बूले', 'आफ्नो', 'भूमिकाप्रति', 'न्याय', 'गरेकी', 'छिन्'], ['नाटक', 'हेर्दै', 'गर्दा', 'उनी', 'कक्षा', 'पढ्दै', 'गरेकी', 'सानी', 'बालिका', 'हुन्', 'जस्तो', 'लाग्दैन'], ['त्यसैगरी', 'चुलबुले', 'विद्यार्थीको', 'भूमिकामा', 'देखिने', 'आकृति', 'तिमल्सेना', 'एक', 'फरक', 'भूमिकामा', 'जुम्लाकी', 'महिलाको', 'कथाव्यथा', 'सुनाएर', 'दर्शकलाई', 'भावुक', 'बनाउन', 'सफल', 'भएकी', 'छिन्'], ['त्यसैगरी', 'तारा', 'लामा', 'खुसी', 'हमाल', 'सामना', 'श्रेष्ठ', 'संगीत', 'श्रेष्ठ', 'आर्यन', 'चन्द', 'अधीश', 'चन्द', 'समृद्धि', 'दाहाल', 'भवेश', 'पौडेल', 'प्रिन्स', 'वाग्लेलगायतले', 'पनि', 'उड्की', 'मुड्कीमा', 'जमेर', 'अभिनय', 'गरेका', 'छन्'], ['लगभग', 'एक', 'घन्टा', 'मिनेट', 'लामो', 'नाटक', 'हेर्दै', 'जाँदा', 'बिचबिचमा', 'आउने', 'देउडादेखि', 'विभिन्न', 'नेपाली', 'तथा', 'अंग्रेजी', 'गीत', 'संगीतले', 'दर्शकलाई', 'मन्त्रमुग्ध', 'बनाउँछन्'], [], ['सांसद', 'गगन', 'थापाले', 'नाटक', 'हेर्दै', 'गर्दा', 'आफूलाई', 'आफ्नो', 'स्कुलका', 'दिनको', 'सम्झना', 'आएको', 'बताए'], ['उड्की', 'मुड्की', 'हेर्दै', 'गर्दा', 'मैले', 'मेरो', 'स्कुलका', 'दिन', 'सम्झिरहेँ', 'थापाले', 'भने', 'नाटकले', 'कतिखेर', 'हँसायो', 'र', 'कतिखे ...

# %%
def build_dataset(words):
    count = collections.Counter(words).most_common()
    dictionary = dict()
    reverse_dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
        reverse_dictionary[len(dictionary)] = dictionary 
    return dictionary, reverse_dictionary
